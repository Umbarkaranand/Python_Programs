# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/Fruits.csv')
df.head()
# Out:
#    Weight   Color    Size    Type
# 0     150     Red  Medium   Apple
# 1     120   Green   Small   Apple
# 2     300  Yellow   Large  Banana
# 3     200  Yellow  Medium  Banana
# 4     100  Orange   Small  Orange

# %%
x = df.drop('Type',axis='columns')
y = df['Type']

# %%
from keras.models import Sequential

model = Sequential()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from keras.models import Sequential
#       3 model = Sequential()
#
# File c:\Users\Swap\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\__init__.py:10
#       7 import os
#       9 # Import everything from /api/ into keras.
# ---> 10 from keras.api import *  # noqa: F403
#      11 from keras.api import __version__  # Import * ignores names start with "_".
#      13 # Add everything in /api/ to the module search path.
#
# File c:\Users\Swap\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\api\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
# ...
